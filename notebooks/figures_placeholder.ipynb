# %% [markdown]
# # Figures (placeholder)
#
# This notebook is reserved for figures after a real run. It does not contain results.
# Do not treat empty or toy plots as empirical findings.

# %%
# Intentionally empty. Generate figures from results/ after training.
print("no figures yet")
